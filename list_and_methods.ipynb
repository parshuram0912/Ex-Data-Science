# %%
list=[3,6,5,25,85,41,23,65]
cars=["tata","maruti","Nissan","audi","toyota","renualt"]
fruits=["apple","banana","cherry","guava","pich","pineapple"]
mix_list=["table",45,25.6,"hundai"]

# %%
cars.pop(3)
cars
# Out:
# ['tata', 'maruti', 'Nissan', 'renualt', 'toyota', 'toyota', 'hundai']

# %%
if "appl" in fruits:   #ist called the membership operator 
    print("yes your item are in the list")
else:
    print("your serch item are not availabel in the store")
# Out:
# your serch item are not availabel in the store
