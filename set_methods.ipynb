# %%
#set is the unique,mutable,unordered collection of element
num=set()
print(type(num))  #to shoew the it define using the name set
# Out:
# <class 'set'>

# %%
num1={25,65,36,45,42,78,98,26}
num2={65,36,52,41,48,78,25,42}

# %%
num1.difference(num2)
# Out:
# {26, 45, 98}
