# %%
#we have use the sting formating in python for better radiabilty and clean code
name="hitesh"
age=25
status="unmarried"

print(f"The name of the employees are {name} his/her age are{age} with the status {status}")
# Out:
# The name of the employees are hitesh his/her age are25 with the status unmarried

# %%
#reming the important thing is that when we write 
name="parshuram"
name.capitalize() 
name#it is not change the main string it creates a new to check the reality
# Out:
# 'parshuram'

# %% [markdown]
# name
