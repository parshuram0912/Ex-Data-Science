# %%
import numpy as np
arr=np.array([1,2,3,4,5,6])
print(arr.dtype)
# Out:
# int64

# %%
print(arr.dtype)
# Out:
# int64

# %%
arr.astype("int32")
# Out:
# array([1, 2, 3, 4, 5, 6], dtype=int32)

# %%
string_array=np.array(["mahindara","tata","toyota","maruti","nissan","skoda" ])
print(string_array)
# Out:
#   Cell In[9], line 1
#     string_array=np.array(["mahindara","tata","toyota","maruti","nissan","skoda" ,dtype='U10'])
#                                                                                   ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
print(string_array.dtype)
# Out:
# <U9
