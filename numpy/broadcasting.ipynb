# %%
import numpy as np
arr=np.array([1,2,3,4,5,6,7])
print(arr)
# Out:
# [1 2 3 4 5 6 7]

# %%
result=[]
for i in arr:
    result=arr*2
print(result)   #this is the simple loop operation
# Out:
# [ 2  4  6  8 10 12 14]

# %%
# now vectirozation
result=arr*2
print(result)
# Out:
# [ 2  4  6  8 10 12 14]

# %%
#broadcasting with two arrays
arr1=np.array([1,2,3])
arr2=np.array([10,20,30])
baddition=arr1+arr2
print(baddition)
# Out:
# [11 22 33]

# %%
#broadcating with 2d and 1d array
arr3=np.array([[1,2,3],[3,4,5,]])
arr4=np.array([3,6,9])
result=arr3+arr4
print(result)
# Out:
# [[ 4  8 12]
#  [ 6 10 14]]

# %%
=
