# %%
import numpy as np
arr=np.array([[1,9,3],[4,3,4],[5,6,7]])
arr
# Out:
# array([[1, 9, 3],
#        [4, 3, 4],
#        [5, 6, 7]])

# %%
sum_arr=np.sum(arr,axis=0)
sum_arr  #it show the addition of the rows
# Out:
# array([ 8, 11, 14])

# %%
print(arr[1][0])
# Out:
# 4

# %%
print(arr[0:2,:3])
# Out:
# [[1 9 3]
#  [4 3 4]]

# %% [markdown]
# The 3d array indexing and slicing
