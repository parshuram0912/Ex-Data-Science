# %%
import numpy as np
import time

size=10000


l1=[1,2,3,4]
l2=[5,6,7,8]

start=time.time()
add=[x+y for x,y in zip(l1,l2)]
end=time.time()

print(end-start)
# Out:
# 0.00037932395935058594

# %%
#now using the numpy arrays
l1=np.array(list(range(size)))
l2=np.array(list(range(size)))
