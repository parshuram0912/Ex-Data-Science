# %%
import numpy as np
arr=np.array([6,25,3,8,96])
print(arr.min())
# Out:
# 3

# %%
arr.max()
# Out:
# np.int64(96)

# %%
arr.mean()
# Out:
# np.float64(27.6)

# %%
arr.std() #it gives a standard daviation of the array
# Out:
# np.float64(35.046255149445)

# %%
np.percentile(arr, 50)  # For the 50th percentile (median)
# Out:
# np.float64(8.0)

# %%
np.prod(arr)
# Out:
# np.int64(345600)

# %%
np.log(arr)
# Out:
# array([1.79175947, 3.21887582, 1.09861229, 2.07944154, 4.56434819])
