# %%
number=int(input("take the fist number you want to displa"))
# Out:
# take the fist number you want to displa 65

# %%
number
# Out:
# 65

# %%
number2=int(input("enter the second number for the addition"))
# Out:
# enter the second number for the addition 63

# %%
add=number+number2

# %%
add
# Out:
# 128
