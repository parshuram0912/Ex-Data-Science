# %%
tup=(65,45,23,78,25,41,45)
tup.count(45) #it shows that duplicates are allowed in the tuple
print(tup[2])
# Out:
# 23

# %% [raw]
# tuple are immutable it are not changabel resons to use tuple are it is not changable

# %%
#unpacking of tuple are 
person=("pravin",20000,25)
name,salary,age=person #it is the method to unpacking the tuple

# %%
name
# Out:
# 'pravin'

# %%
salary
# Out:
# 20000

# %%
age
# Out:
# 25
