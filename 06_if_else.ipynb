# %%
a=50

# %%
if(a>=60):
    print("greather")
else:
    print("small")
# Out:
# small

# %%
if(a>70):
    print("the a is greather than 40")
elif(a==50):
    print("a is the exactely value")
elif(a<45):
    print("the a is missing value")
else:
    print("the a is the best value")  #when we use the mathc condition stament more than one time it will execute the first statement only
# Out:
# a is the exactely value

# %%
def http_status(code):
    match code:
        case 200:
            return "OK"
        case 400:
            return "Bad Request"
        case 404:
            return "Not Found"
        case 500:
            return "Internal Server Error"
        case _:
            return "Unknown Status"

print(http_status(200))  # Output: OK
print(http_status(404))  # Output: Not Found
# Out:
# OK
# Not Found

# %%
#we can use the tuple for the match case 
point=(6,0)
match point:
    case (0,6):
        print("the x axis is o")
    case (6,0):
        print("the x axis is 6")
    case _:
        print("the wrong axis")
# Out:
# the x axis is 6
