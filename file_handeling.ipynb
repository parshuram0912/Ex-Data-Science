# %%
f=open("parshuram.txt","r")
f.read()  #this the method to read the file actually available fiel in python
f.close()

# %%
tes="i have successfully added the text with new file"
f=open("akash.txt","w")
f.write(tes)
f.close()

# %%
fil=open("parshuram.txt","a")
fil.write("this the additional line using append function")
fil.close()

# %%
#with open statement practice how to open the file

with open("parshuram.txt","r") as file:
    data=file.read()
    print(data)

    #in this type of file operation there is no need to manually closed file it will automatically closed the file
# Out:
# now i have learn about python file handeling in which the r denotens file are open in read mode
# and the file are open in write modes for wthis the additional line using append function

# %%
#how to check the file are exist or not usin os path befor start we can import os module
import os

if os.path.exists("akash.txt"):
    print("file are exist")
else:
    print("file are not exist")
# Out:
# file are exist

# %%
import os

if os.path.exists("example.txt"):
    os.remove("example.txt")
    print("File deleted.")
else:
    print("File does not exist.")
# Out:
# File does not exist.

# %%
import os

if os.path.exists("example.txt"):
    print("File exists!")
else:
    print("File not found!")
# Out:
# File not found!
