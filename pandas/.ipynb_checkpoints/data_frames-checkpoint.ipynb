# %%
# fisrt we create a dataframes using the array
import numpy as np
arr=np.array([[1,2],[3,4],[5,6]])
print(arr)
# Out:
# [[1 2]
#  [3 4]
#  [5 6]]

# %%
#now this array we can convert it into the Dataframes
import pandas as pd
df=pd.DataFrame(arr,index=["a","b","c"])
print(df)
# Out:
#    0  1
# a  1  2
# b  3  4
# c  5  6

# %%
#now we try the data frame using the file
# dc=pd.DataFrame(student.xlsx)
# print(dc)
dc=pd.read_excel("C:/Users/parsh/Desktop/Data science/student.xlsx",header=2)
dc = dc.dropna(axis=1, how="all")
dc = dc.dropna(axis=0, how="any")
print(dc)
# Out:
#     Unnamed: 1 Unnamed: 2 Unnamed: 3
# 0         name     school      marks
# 1    parshuram        vmp         46
# 2        akash       vjti         85
# 3        bindu        sgs         25
# 4   prathamesh        sgm         63
# 5      sanket        cals         85
# 6         balu       bart         56
# 7       jayesh        bos         45
# 8       jaying        vmp         35
# 9        sumit     telcom         85
# 10      raghav       brav         64
# 11      baldev        bat         65

# %%
#now we read the  file using the json file 
df=pd.read_json("C:/Users/parsh/Desktop/Data science/data.json")
print(df)   #the file is inside the directory otherwise give a full path of the file
# Out:
#       name  age         city
# 0    Alice   25     New York
# 1      Bob   30  Los Angeles
# 2  Charlie   35      Chicago
