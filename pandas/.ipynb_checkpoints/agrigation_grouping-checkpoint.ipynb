# %%
import pandas as pd
df = pd.DataFrame({
    "Department": ["HR", "HR", "IT", "IT", "Marketing", "Marketing", "Sales", "Sales"],
    "Team": ["A", "A", "B", "B", "C", "C", "D", "D"],
    "Gender": ["M", "F", "M", "F", "M", "F", "M", "F"],
    "Salary": [85, 90, 78, 85, 92, 88, 75, 80],
    "Age": [23, 25, 30, 22, 28, 26, 21, 27],
    "JoinDate": pd.to_datetime([
        "2020-01-10", "2020-02-15", "2021-03-20", "2021-04-10",
        "2020-05-30", "2020-06-25", "2021-07-15", "2021-08-01"
    ])
})  
print(df)

df.groupby("Gender")["Age"].mean()
# Out:
#   Department Team Gender  Salary  Age   JoinDate
# 0         HR    A      M      85   23 2020-01-10
# 1         HR    A      F      90   25 2020-02-15
# 2         IT    B      M      78   30 2021-03-20
# 3         IT    B      F      85   22 2021-04-10
# 4  Marketing    C      M      92   28 2020-05-30
# 5  Marketing    C      F      88   26 2020-06-25
# 6      Sales    D      M      75   21 2021-07-15
# 7      Sales    D      F      80   27 2021-08-01

# %%
df.groupby("Gender")["Age"].max()
# Out:
# Gender
# F    27
# M    30
# Name: Age, dtype: int64

# %%
df.groupby("Team")["Age"].agg(max_age="max",min_age="min")
# Out:
#       max_age  min_age
# Team
# A          25       23
# B          30       22
# C          28       26
# D          27       21

# %%
df["Team Avg"] = df.groupby("Team")["Salary"].transform("max")
df
# Out:
#   Department Team Gender  Salary  Age   JoinDate  Team Avg
# 0         HR    A      M      85   23 2020-01-10        90
# 1         HR    A      F      90   25 2020-02-15        90
# 2         IT    B      M      78   30 2021-03-20        85
# 3         IT    B      F      85   22 2021-04-10        85
# 4  Marketing    C      M      92   28 2020-05-30        92
# 5  Marketing    C      F      88   26 2020-06-25        92
# 6      Sales    D      M      75   21 2021-07-15        80
# 7      Sales    D      F      80   27 2021-08-01        80

# %%
df.groupby("Team").filter(lambda x: x["Salary"].mean() > 88)
# Out:
#   Department Team Gender  Salary  Age   JoinDate  Team Avg
# 4  Marketing    C      M      92   28 2020-05-30        92
# 5  Marketing    C      F      88   26 2020-06-25        92
