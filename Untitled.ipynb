# %%
#here is the quick tour of python programming
a=9

b=5
a+b
# Out:
# 14

# %%
str="   parshuram"

# %%
print(str)
# Out:
# parshuram

# %%
#this a comment
print(type(str))
# Out:
# <class 'type'>

# %%
print(type(a))
# Out:
# <class 'int'>

# %%
a="2356"
b="658"
int(a)+int(b) #type casting
# Out:
# 3014
