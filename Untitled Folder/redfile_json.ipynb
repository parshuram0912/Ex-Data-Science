# %%
import json
data_json={
    "users": [
        {"id": 1, "name": "Amit", "friends": [2, 3], "liked_pages": [101]},
        {"id": 2, "name": "Priya", "friends": [1, 4], "liked_pages": [102]},
        {"id": 3, "name": "Rahul", "friends": [1], "liked_pages": [101, 103]},
        {"id": 4, "name": "Sara", "friends": [2], "liked_pages": [104]}
    ],
    "pages": [
        {"id": 101, "name": "Python Developers"},
        {"id": 102, "name": "Data Science Enthusiasts"},
        {"id": 103, "name": "AI & ML Community"},
        {"id": 104, "name": "Web Dev Hub"}
    ]
}
with open("data.json","w") as file:
    json.dump(data_json, file, indent=4)
    
    #i have create the folder name data.json and all data are include in it

# %%
def red_json(filename):
    with open(filename,"r") as f:
       readiable_data= json.load(f)
       return readiable_data
 # "users": [
 #        {"id": 1, "name": "Amit", "friends": [2, 3], "liked_pages": [101]},
 #        {"id": 2, "name": "Priya", "friends": [1, 4], "liked_pages": [102]},
 #        {"id": 3, "name": "Rahul", "friends": [1], "liked_pages": [101, 103]},
 #        {"id": 4, "name": "Sara", "friends": [2], "liked_pages": [104]}
 #    ],
 #    "pages": [
 #        {"id": 101, "name": "Python Developers"},
 #        {"id": 102, "name": "Data Science Enthusiasts"},
 #        {"id": 103, "name": "AI & ML Community"},
 #        {"id": 104, "name": "Web Dev Hub"}
 #    ]

def show_detail(your_data):
    # Iterate through users
    for user in your_data["users"]:
        print(f"The id {user['id']} has name {user['name']}, his friends are {user['friends']}, and the liked pages are {user['liked_pages']}")
    
    # Iterate through pages specifically
    for page in your_data["pages"]:
        print(f"The id {page['id']} is the {page['name']}")

# %%
py_string=red_json("data.json")
detail=show_detail(py_string)
# Out:
# The id 1 has name Amit, his friends are [2, 3], and the liked pages are [101]
# The id 2 has name Priya, his friends are [1, 4], and the liked pages are [102]
# The id 3 has name Rahul, his friends are [1], and the liked pages are [101, 103]
# The id 4 has name Sara, his friends are [2], and the liked pages are [104]
# The id 101 is the Python Developers
# The id 102 is the Data Science Enthusiasts
# The id 103 is the AI & ML Community
# The id 104 is the Web Dev Hub
