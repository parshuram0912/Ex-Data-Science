# %%
# The Master Data Structure
database = {
    "company": "TechCorp",
    "established": 2015,
    "is_active": True,
    "departments": {
        "engineering": {
            "head": "Alice",
            "employees": [
                {"id": 1, "name": "Bob", "skills": ["Python", "AWS"]},
                {"id": 2, "name": "Charlie", "skills": ["Java", "SQL"]}
            ]
        },
        "hr": {
            "head": "Diana",
            "employees": ["Eve", "Frank"]
        }
    }
}

print(type(database))
print(f"the name of the company is{database["company"]} and the employee id with the skill{database["departments"]["engineering"]["employees"]["skills"]")
# Out:
#   Cell In[4], line 22
#     print(f"the name of the company is{database["company"]} and the employee id with the skill{database["departments"]["engineering"]["employees"]["skills"]")
#                                                                                                                                                             ^
# SyntaxError: f-string: expecting '}'
